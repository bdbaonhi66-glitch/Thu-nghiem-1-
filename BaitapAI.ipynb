# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import os

pd.set_option('display.max_columns', None)

print("Import thư viện thành công")
# Out:
# Import thư viện thành công

# %%
# Đường dẫn dữ liệu
data_path = "./"

# Lấy danh sách file CSV
csv_files = glob(os.path.join(data_path, "*.csv"))

print("Số file CSV:", len(csv_files))
print(csv_files[:5])
# Out:
# Số file CSV: 13
# ['.\\dl.csv', '.\\PRSA_Data_Aotizhongxin_20130301-20170228.csv', '.\\PRSA_Data_Changping_20130301-20170228.csv', '.\\PRSA_Data_Dingling_20130301-20170228.csv', '.\\PRSA_Data_Dongsi_20130301-20170228.csv']

# %%
df_list = []

for file in csv_files:
    temp_df = pd.read_csv(file)
    df_list.append(temp_df)

df = pd.concat(df_list, ignore_index=True)

print("Kích thước dữ liệu:", df.shape)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 df_list = []
#       3 for file in csv_files:
# ----> 4     temp_df = pd.read_csv(file)
#       5     df_list.append(temp_df)
#       7 df = pd.concat(df_list, ignore_index=True)
#
# ...

# %%
from glob import glob

csv_files = glob("*.csv")

print(csv_files)
# Out:
# ['dl.csv', 'PRSA_Data_Aotizhongxin_20130301-20170228.csv', 'PRSA_Data_Changping_20130301-20170228.csv', 'PRSA_Data_Dingling_20130301-20170228.csv', 'PRSA_Data_Dongsi_20130301-20170228.csv', 'PRSA_Data_Guanyuan_20130301-20170228.csv', 'PRSA_Data_Gucheng_20130301-20170228.csv', 'PRSA_Data_Huairou_20130301-20170228.csv', 'PRSA_Data_Nongzhanguan_20130301-20170228.csv', 'PRSA_Data_Shunyi_20130301-20170228.csv', 'PRSA_Data_Tiantan_20130301-20170228.csv', 'PRSA_Data_Wanliu_20130301-20170228.csv', 'PRSA_Data_Wanshouxigong_20130301-20170228.csv']

# %%
import pandas as pd

df_list = []

for file in csv_files:
    print("Đang đọc:", file)

    temp_df = pd.read_csv(file)

    df_list.append(temp_df)

df = pd.concat(df_list, ignore_index=True)

print(df.shape)
# Out:
# Đang đọc: dl.csv
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 8
#       5 for file in csv_files:
#       6     print("Đang đọc:", file)
# ----> 8     temp_df = pd.read_csv(file)
#      10     df_list.append(temp_df)
#      12 df = pd.concat(df_list, ignore_index=True)
#
# ...

# %%
temp_df = pd.read_csv(file, encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 temp_df = pd.read_csv(file, encoding='latin1')
#
# File ~\anaconda3\envs\airquality\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
temp_df = pd.read_csv(file, encoding='gbk')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 temp_df = pd.read_csv(file, encoding='gbk')
#
# File ~\anaconda3\envs\airquality\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
from glob import glob

csv_files = glob("PRSA*.csv")

df_list = []

for file in csv_files:
    temp_df = pd.read_csv(file)
    df_list.append(temp_df)

df = pd.concat(df_list, ignore_index=True)

print(df.head())
print(df.shape)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
# (420768, 18)

# %%
import pandas as pd
from glob import glob

# Lấy các file CSV của dataset
csv_files = glob("PRSA*.csv")

df_list = []

for file in csv_files:
    
    try:
        print("Đang đọc:", file)

        temp_df = pd.read_csv(file)

        df_list.append(temp_df)

    except Exception as e:
        print(f"Lỗi file {file}: {e}")

# Gộp dữ liệu
df = pd.concat(df_list, ignore_index=True)

print("Kích thước dữ liệu:", df.shape)

df.head()
# Out:
# Đang đọc: PRSA_Data_Aotizhongxin_20130301-20170228.csv
# Đang đọc: PRSA_Data_Changping_20130301-20170228.csv
# Đang đọc: PRSA_Data_Dingling_20130301-20170228.csv
# Đang đọc: PRSA_Data_Dongsi_20130301-20170228.csv
# Đang đọc: PRSA_Data_Guanyuan_20130301-20170228.csv
# Đang đọc: PRSA_Data_Gucheng_20130301-20170228.csv
# Đang đọc: PRSA_Data_Huairou_20130301-20170228.csv
# Đang đọc: PRSA_Data_Nongzhanguan_20130301-20170228.csv
# Đang đọc: PRSA_Data_Shunyi_20130301-20170228.csv
# Đang đọc: PRSA_Data_Tiantan_20130301-20170228.csv
# Đang đọc: PRSA_Data_Wanliu_20130301-20170228.csv
# Đang đọc: PRSA_Data_Wanshouxigong_20130301-20170228.csv
# Kích thước dữ liệu: (420768, 18)
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
df.isnull().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
df['datetime'] = pd.to_datetime(
    df[['year', 'month', 'day', 'hour']]
)

# %%
pm25_station = df.groupby('station')['PM2.5'].mean()

print(pm25_station)
# Out:
# station
# Aotizhongxin     82.773611
# Changping        71.099743
# Dingling         65.989497
# Dongsi           86.194297
# Guanyuan         82.933372
# Gucheng          83.852089
# Huairou          69.626367
# Nongzhanguan     84.838483
# Shunyi           79.491602
# Tiantan          82.164911
# Wanliu           83.374716
# Wanshouxigong    85.024136
# Name: PM2.5, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

pm25_station.plot(kind='bar')

plt.title("PM2.5 trung bình theo trạm")

plt.show()

# %%
glob("PRSA*.csv")
# Out:
# ['PRSA_Data_Aotizhongxin_20130301-20170228.csv',
#  'PRSA_Data_Changping_20130301-20170228.csv',
#  'PRSA_Data_Dingling_20130301-20170228.csv',
#  'PRSA_Data_Dongsi_20130301-20170228.csv',
#  'PRSA_Data_Guanyuan_20130301-20170228.csv',
#  'PRSA_Data_Gucheng_20130301-20170228.csv',
#  'PRSA_Data_Huairou_20130301-20170228.csv',
#  'PRSA_Data_Nongzhanguan_20130301-20170228.csv',
#  'PRSA_Data_Shunyi_20130301-20170228.csv',
#  'PRSA_Data_Tiantan_20130301-20170228.csv',
#  'PRSA_Data_Wanliu_20130301-20170228.csv',
#  'PRSA_Data_Wanshouxigong_20130301-20170228.csv']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User
